# %%
import torch
import torch.nn as nn
from torch.nn import Parameter
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Making an LSTM from scratch
#
# ### To start you will be filling in the blanks to create your own LSTM.
# ### Here are the equations you will need:
#
# $f_t=σ(W_{fx}\cdot x_t+W_{fh}\cdot h_t+b_f)$
#
# $i_t=σ(W_{ix}\cdot x_t+W_{ih}\cdot h_t+b_i)$
#
# $\tilde c_t=tanh(W_{cx}\cdot x_t+W_{ch}\cdot h_t+b_c)$
#
# $o_t=σ(W_{ox}\cdot x_t+W_{oh}\cdot h_t+b_o)$
#
# $C_t=f_t∗C_t+i_t∗\tilde c_t$
#
# $h_t=o_t∗tanh(C_t)$
#
# ### and here are the matrix and vector sizes you will need to know:
#
# $H$ = size of hidden state, $I$ = size of input features
#
# $f_t,i_t,\tilde c_t,o_t,h_t,C_t = H \times 1$
#
# $x_t = I \times 1$
#
# $W_{fx},W_{ix},W_{cx},W_{ox} = H \times I$
#
# $W_{fh},W_{ih},W_{ch},W_{oh} = H \times H$
#
# $b_{f},b_{i},b_{c},b_{o} = H \times 1$

# %%
class LSTM(nn.Module):
    def __init__(self,inputsz,hiddensz):
        super().__init__()
        self.inputsz=inputsz
        self.hiddensz=hiddensz  
        
        # input gate
        self.Wix =  Parameter(torch.Tensor(self.hiddensz, self.inputsz)) 
        self.Wih = Parameter(torch.Tensor(self.hiddensz, self.hiddensz)) 
        self.bi = Parameter(torch.Tensor(self.hiddensz, 1)) 
        
        #forget gate
        self.Wfx = Parameter(torch.Tensor(self.hiddensz, self.inputsz))
        self.Wfh = Parameter(torch.Tensor(self.hiddensz, self.hiddensz))
        self.bf = Parameter(torch.Tensor(self.hiddensz, 1))
        
        #c gate
        self.Wcx = Parameter(torch.Tensor(self.hiddensz, self.inputsz))
        self.Wch = Parameter(torch.Tensor(self.hiddensz, self.hiddensz))
        self.bc = Parameter(torch.Tensor(self.hiddensz, 1))
        
        #output gate
        self.Wox = Parameter(torch.Tensor(self.hiddensz, self.inputsz))
        self.Woh = Parameter(torch.Tensor(self.hiddensz, self.hiddensz))
        self.bo = Parameter(torch.Tensor(self.hiddensz, 1))
        
        
        #paramter initialization
        for p in self.parameters():  
            if p.data.ndimension()>=2:
                nn.init.xavier_uniform_(p.data)
            else:
                nn.init.zeros_(p.data)
                
    def forward(self,x,initstates=None):
        m = len(x)
        hidden_seq = []
        if initstates is None:
            ht,ct = torch.zeros((self.hiddensz, 1)), torch.zeros((self.hiddensz, 1))
        else:
            ht,ct = initstates
        for t in range(m):
            xt = x[t,:]
            it =   torch.sigmoid(self.Wix @ xt + self.Wih @ ht + self.bi)
            ft =   torch.sigmoid(self.Wfx @ xt + self.Wfh @ ht + self.bf)
            gt =   torch.tanh(self.Wcx @ xt + self.Wch @ ht + self.bc)
            ot =   torch.sigmoid(self.Wox @ xt + self.Woh @ ht + self.bo)
            ct =   ft * ct + it * gt
            ht =   ot * torch.tanh(ct)
            
            hidden_seq.append(ht.unsqueeze(0))
        hidden_seq = torch.cat(hidden_seq,dim=0)
        return hidden_seq, (ht,ct)

# %%
class customDataset(Dataset):

    def __init__(self, x, transform=None):
        self.data = x
        

    def __len__(self):
        return len(self.data)

    def __getitem__(self, i):
        return self.data[i]

# %% [markdown]
# # Addition
#
# ### First we are going to be teaching the LSTM to do addition.

# %%
def addData(size):
    size = np.random.choice(range(size,size+int(size/10)))
    inputs = torch.Tensor([[np.random.uniform(-.5,.5),0] for i in range(size)])
    choice1 = np.random.choice(range(1,10))
    choice2 = list(range(1,int(size/2)))
    choice2.remove(choice1)
    choice2 = np.random.choice(choice2)
    inputs[choice1,1]=1
    inputs[choice2,1]=1
    label = inputs[:,0][inputs[:,1]==1].sum()
    return inputs,label

# %% [markdown]
# ### Here's a look at the data. The goal is to learn to add the numbers in the left row that have a corresponding 1 in the right row while ignoring the rest.

# %%
addData(20)
# Out:
# (tensor([[-0.0343,  0.0000],
#          [ 0.0105,  0.0000],
#          [ 0.3497,  0.0000],
#          [ 0.3407,  0.0000],
#          [ 0.2468,  1.0000],
#          [-0.0293,  0.0000],
#          [-0.2859,  0.0000],
#          [-0.1585,  0.0000],
#          [ 0.0594,  0.0000],
#          [-0.1443,  1.0000],
#          [-0.4187,  0.0000],
#          [-0.4853,  0.0000],
#          [ 0.1978,  0.0000],
#          [ 0.4395,  0.0000],
#          [-0.1071,  0.0000],
#          [-0.1063,  0.0000],
#          [ 0.0933,  0.0000],
#          [ 0.1906,  0.0000],
#          [ 0.3468,  0.0000],
#          [-0.1742,  0.0000]]), tensor(0.1025))

# %%
size = 20

train = customDataset([addData(size) for i in range(20)])
train_loader = DataLoader(train,batch_size = 1, shuffle = False)

val = customDataset([addData(size) for i in range(20)])
val_loader = DataLoader(val,batch_size = 1, shuffle = False)

test = customDataset([addData(size) for i in range(100)])
test_loader = DataLoader(test,batch_size = 1, shuffle = False)

# %%
featsz, hiddensz = 2, 1
model = LSTM(featsz, hiddensz)
# Define hyperparameters
n_epochs = 100
lr=.02

# Define Loss, Optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr,weight_decay = .0001)

# %%
print(model.Wix.size())
# Out:
# torch.Size([1, 2])

# %%
for epoch in range(1, n_epochs + 1):
    model.train()
    hidden = torch.zeros(hiddensz),torch.zeros(hiddensz)
    losslist = []
    for d,t in train_loader:
        optimizer.zero_grad()
        output, hidden = model(d.squeeze(0),hidden)
        loss = criterion(output.sum(), t)
        
        loss.backward(retain_graph=True)
        losslist.append(loss.item())
        optimizer.step()
    model.eval()
    validationlist = []
    for d,t in val_loader:
        output,hidden = model(d.squeeze(0))
        loss = criterion(output.sum(), t)
        validationlist.append(loss.item())
    currval = np.mean(validationlist)
    print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
    print("training: {:.4f},val Loss: {:.4f}".format(np.mean(losslist),currval))
# Out:
# /home/mand-faced-god/.local/lib/python3.6/site-packages/torch/nn/modules/loss.py:431: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch: 1/100............. training: 6.7866,val Loss: 2.3618
# Epoch: 2/100............. training: 1.3687,val Loss: 0.5854
# Epoch: 3/100............. training: 0.4211,val Loss: 0.2513
# Epoch: 4/100............. training: 0.2285,val Loss: 0.1986
# Epoch: 5/100............. training: 0.1915,val Loss: 0.1947
# Epoch: 6/100............. training: 0.1830,val Loss: 0.1932
# Epoch: 58/100............. training: 0.0477,val Loss: 0.0836
# Epoch: 59/100............. training: 0.0448,val Loss: 0.0809
# Epoch: 60/100............. training: 0.0422,val Loss: 0.0783
# Epoch: 61/100............. training: 0.0397,val Loss: 0.0758
# Epoch: 62/100............. training: 0.0374,val Loss: 0.0733
# Epoch: 63/100............. training: 0.0353,val Loss: 0.0708
# Epoch: 64/100............. training: 0.0332,val Loss: 0.0682
# Epoch: 65/100............. training: 0.0313,val Loss: 0.0657
# Epoch: 66/100............. training: 0.0295,val Loss: 0.0632
# Epoch: 67/100............. training: 0.0278,val Loss: 0.0607
# Epoch: 68/100............. training: 0.0263,val Loss: 0.0581
# Epoch: 69/100............. training: 0.0248,val Loss: 0.0556
# Epoch: 70/100............. training: 0.0234,val Loss: 0.0530
# Epoch: 71/100............. training: 0.0221,val Loss: 0.0505
# Epoch: 72/100............. training: 0.0208,val Loss: 0.0481
# Epoch: 73/100............. training: 0.0197,val Loss: 0.0457
# Epoch: 74/100............. training: 0.0186,val Loss: 0.0433
# Epoch: 75/100............. training: 0.0177,val Loss: 0.0411
# Epoch: 76/100............. training: 0.0168,val Loss: 0.0389
# Epoch: 77/100............. training: 0.0159,val Loss: 0.0368
# Epoch: 78/100............. training: 0.0151,val Loss: 0.0348
# Epoch: 79/100............. training: 0.0144,val Loss: 0.0329
# Epoch: 80/100............. training: 0.0137,val Loss: 0.0311
# Epoch: 81/100............. training: 0.0131,val Loss: 0.0294
# Epoch: 82/100............. training: 0.0125,val Loss: 0.0278
# Epoch: 83/100............. training: 0.0120,val Loss: 0.0263
# Epoch: 84/100............. training: 0.0115,val Loss: 0.0249
# Epoch: 85/100............. training: 0.0111,val Loss: 0.0236
# Epoch: 86/100............. training: 0.0107,val Loss: 0.0223
# Epoch: 87/100............. training: 0.0103,val Loss: 0.0212
# Epoch: 88/100............. training: 0.0100,val Loss: 0.0201
# Epoch: 89/100............. training: 0.0097,val Loss: 0.0192
# Epoch: 90/100............. training: 0.0094,val Loss: 0.0183
# Epoch: 91/100............. training: 0.0092,val Loss: 0.0174
# Epoch: 92/100............. training: 0.0090,val Loss: 0.0167
# Epoch: 93/100............. training: 0.0088,val Loss: 0.0159
# Epoch: 94/100............. training: 0.0086,val Loss: 0.0153
# Epoch: 95/100............. training: 0.0084,val Loss: 0.0147
# Epoch: 96/100............. training: 0.0083,val Loss: 0.0141
# Epoch: 97/100............. training: 0.0082,val Loss: 0.0136
# Epoch: 98/100............. training: 0.0081,val Loss: 0.0132
# Epoch: 99/100............. training: 0.0080,val Loss: 0.0128
# Epoch: 100/100............. training: 0.0079,val Loss: 0.0124

# %%
model.eval()
predictions = []
labels = []
for d,t in test_loader:
    output,hidden = model(d.squeeze(0))
    predictions.append(output.sum())
    labels.append(t)
plt.figure(figsize=(15,12))
plt.plot(predictions,'r-', label="Predictions")
plt.plot(labels,'b-', label="Labels")
plt.legend()

# %% [markdown]
# # Multiplication

# %% [markdown]
# ### Now we'll be trying to learn to multiply. The goal is essentially the same except instead of adding the two numbers we multiply them.

# %%
def multData(size):
    size = np.random.choice(range(size,size+int(size/10)))
    inputs = torch.Tensor([[np.random.uniform(0,1),0] for i in range(size)])
    choice1 = np.random.choice(range(1,10))
    choice2 = list(range(1,int(size/2)))
    choice2.remove(choice1)
    choice2 = np.random.choice(choice2)
    inputs[choice1,1]=1
    inputs[choice2,1]=1
    label = inputs[:,0][inputs[:,1]==1].prod()
    return inputs,label

# %%
size = 20
train = customDataset([multData(size) for i in range(20)])
train_loader = DataLoader(train,batch_size = 1, shuffle = False)

val = customDataset([multData(size) for i in range(20)])
val_loader = DataLoader(val,batch_size = 1, shuffle = False)


test = customDataset([multData(size) for i in range(40)])
test_loader = DataLoader(test,batch_size = 1, shuffle = False)

# %%
featsz, hiddensz = 2, 1
model = LSTM(featsz, hiddensz)
# Define hyperparameters
n_epochs = 1000
lr=.02

# Define Loss, Optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr,weight_decay = .0001)

# %%
model.train()
minimum = 100
n_epochs = 100
for epoch in range(1, n_epochs + 1):
    model.train()
    hidden = torch.zeros(hiddensz),torch.zeros(hiddensz)
    
    losslist = []
    for d,t in train_loader:
        optimizer.zero_grad()
        output, hidden = model(d.squeeze(0),hidden)
        loss = criterion(hidden[0], t)
        loss.backward(retain_graph=True)
        losslist.append(loss.item())
        optimizer.step()
    model.eval()
    validationlist = []
    for d,t in val_loader:
        output,hidden = model(d.squeeze(0))
        predictions.append(hidden[0].item())
        labels.append(t.item())
        loss = criterion(hidden[0], t)
        validationlist.append(loss.item())
    currval = np.mean(validationlist)
    print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
    print("training: {:.4f},val Loss: {:.4f}".format(np.mean(losslist),currval))
# Out:
# Epoch: 1/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 2/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 3/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 4/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 5/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 6/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 7/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 8/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 9/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 10/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 11/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 12/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 13/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 14/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 15/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 16/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 17/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 18/100............. training: 0.0362,val Loss: 0.0329
# Epoch: 19/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 20/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 21/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 22/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 23/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 24/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 25/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 26/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 27/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 28/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 29/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 30/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 31/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 32/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 33/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 34/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 35/100............. training: 0.0361,val Loss: 0.0329
# Epoch: 36/100............. training: 0.0360,val Loss: 0.0329
# Epoch: 37/100............. training: 0.0360,val Loss: 0.0329
# Epoch: 38/100............. training: 0.0360,val Loss: 0.0329
# Epoch: 39/100............. training: 0.0360,val Loss: 0.0329
# Epoch: 40/100............. training: 0.0360,val Loss: 0.0329
# Epoch: 41/100............. training: 0.0360,val Loss: 0.0329
# Epoch: 42/100............. training: 0.0360,val Loss: 0.0329
# Epoch: 43/100............. training: 0.0360,val Loss: 0.0329
# Epoch: 44/100............. training: 0.0360,val Loss: 0.0329
# Epoch: 45/100............. training: 0.0360,val Loss: 0.0328
# Epoch: 46/100............. training: 0.0360,val Loss: 0.0328
# Epoch: 47/100............. training: 0.0360,val Loss: 0.0328
# Epoch: 48/100............. training: 0.0360,val Loss: 0.0328
# Epoch: 49/100............. training: 0.0360,val Loss: 0.0328
# Epoch: 50/100............. training: 0.0360,val Loss: 0.0328
# Epoch: 51/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 52/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 53/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 54/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 55/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 56/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 57/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 58/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 59/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 60/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 61/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 62/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 63/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 64/100............. training: 0.0359,val Loss: 0.0328
# Epoch: 65/100............. training: 0.0358,val Loss: 0.0328
# Epoch: 66/100............. training: 0.0358,val Loss: 0.0328
# Epoch: 67/100............. training: 0.0358,val Loss: 0.0328
# Epoch: 68/100............. training: 0.0358,val Loss: 0.0328
# Epoch: 69/100............. training: 0.0358,val Loss: 0.0328
# Epoch: 70/100............. training: 0.0358,val Loss: 0.0328
# Epoch: 71/100............. training: 0.0358,val Loss: 0.0328
# Epoch: 72/100............. training: 0.0358,val Loss: 0.0328
# Epoch: 73/100............. training: 0.0358,val Loss: 0.0328
# Epoch: 74/100............. training: 0.0358,val Loss: 0.0328
# Epoch: 75/100............. training: 0.0358,val Loss: 0.0327
# Epoch: 76/100............. training: 0.0358,val Loss: 0.0327
# Epoch: 77/100............. training: 0.0357,val Loss: 0.0327
# Epoch: 78/100............. training: 0.0357,val Loss: 0.0327
# Epoch: 79/100............. training: 0.0357,val Loss: 0.0327
# Epoch: 80/100............. training: 0.0357,val Loss: 0.0327
# Epoch: 81/100............. training: 0.0357,val Loss: 0.0327
# Epoch: 82/100............. training: 0.0357,val Loss: 0.0327
# Epoch: 83/100............. training: 0.0357,val Loss: 0.0327
# Epoch: 84/100............. training: 0.0357,val Loss: 0.0327
# Epoch: 85/100............. training: 0.0357,val Loss: 0.0327
# Epoch: 86/100............. training: 0.0357,val Loss: 0.0327
# Epoch: 87/100............. training: 0.0356,val Loss: 0.0327
# Epoch: 88/100............. training: 0.0356,val Loss: 0.0327
# Epoch: 89/100............. training: 0.0356,val Loss: 0.0327
# Epoch: 90/100............. training: 0.0356,val Loss: 0.0327
# Epoch: 91/100............. training: 0.0356,val Loss: 0.0327
# Epoch: 92/100............. training: 0.0356,val Loss: 0.0327
# Epoch: 93/100............. training: 0.0356,val Loss: 0.0327
# Epoch: 94/100............. training: 0.0356,val Loss: 0.0327
# Epoch: 95/100............. training: 0.0356,val Loss: 0.0327
# Epoch: 96/100............. training: 0.0356,val Loss: 0.0327
# Epoch: 97/100............. training: 0.0355,val Loss: 0.0327
# Epoch: 98/100............. training: 0.0355,val Loss: 0.0327
# Epoch: 99/100............. training: 0.0355,val Loss: 0.0326
# Epoch: 100/100............. training: 0.0355,val Loss: 0.0326

# %%
model.eval()
predictions = []
labels = []
for d,t in test_loader:
    output,hidden = model(d.squeeze(0))
    predictions.append(hidden[0])
    labels.append(t)
plt.figure(figsize=(15,12))
plt.plot(predictions,'r-')
plt.plot(labels,'b-')

# %% [markdown]
# # Questions
#
# 1. Why is addition easy for the LSTM to learn?
#
#
# 2. Why is multiplication harder for the LSTM to learn?

# %% [markdown]
# # Answers
# ---
# 1. It is easier because addition is an easier algorithm.
# 2. It is harder because multiplication is a harder algorithm. It would be interesting to try adding another LSTM ontop of this one to see if it learns multiplication easier.

# %% [markdown]
# # Language Model
#
# ### Here we'll be teaching a model to produce shakespeare. It's a slow a task so we'll be using a more optimized and slightly changed LSTM to do it. The weight matrices have been stacked to reduce the number of matrix multiplications performed and the output now has its own weight matrix. You just need to fill in the function with the correct part of the gates matrix.

# %%
class betterLSTM(nn.Module):
    def __init__(self,inputsz,hiddensz):
        super().__init__()
        self.inputsz=inputsz
        self.hiddensz=hiddensz
        
        #input gate
        self.Wx =  Parameter(torch.Tensor(hiddensz*4,inputsz))
        self.Wh = Parameter(torch.Tensor(hiddensz*4,hiddensz))
        self.Wy = Parameter(torch.Tensor(inputsz,hiddensz))
        self.by = Parameter(torch.Tensor(inputsz,1))
        self.b = Parameter(torch.Tensor(hiddensz*4,1))
        #paramter initialization
        for p in self.parameters():
            if p.data.ndimension()>=2:
                nn.init.xavier_uniform_(p.data)
            else:
                nn.init.zeros_(p.data)
                
    def forward(self,x,initstates=None):
        m = len(x)
        hidden_seq = []
        if initstates is None:
            ht,ct = torch.zeros(self.hiddensz,1),torch.zeros(self.hiddensz,1)
        else:
            ht,ct = initstates
        xt = x
        gates = self.Wx@xt+self.Wh@ht+self.b
        it = torch.sigmoid(gates[:hiddensz, :]) 
        ft = torch.sigmoid(gates[hiddensz:2*hiddensz, :]) 
        gt = torch.tanh(gates[2*hiddensz:3*hiddensz, :]) 
        ot = torch.sigmoid(gates[3*hiddensz:4*hiddensz, :]) 
        ct = ft*ct+it*gt
        ht = ot*torch.tanh(ct)
        output = self.Wy@ht+self.by
        return output, (ht,ct)

# %% [markdown]
# ### Here we load the data and transform it into one-hot vectors.

# %%
file = open('clean_shakespeare.txt','r')
text = file.read()
letters = 'abcdefghijklmnopqrstuvwxyz '
# one hot encode characters
char_dict = {}
for i,char in enumerate(letters):
    vec = torch.zeros(27)
    vec[i] += 1
    char_dict[char] = vec

total_data = 40000

D = []
for i in range(total_data):
    x = text[i]
    y = text[i+1]
    D.append((char_dict[x],char_dict[y]))


featsz, hiddensz = 27, 64
model = betterLSTM(featsz, hiddensz)

# %% [markdown]
# ### This function generates text with our model. You can try different seeds to see what you get. "rand" influences randomness in the text generation and "size" determines how many characters will be produced.

# %%
seed = 'to be or not to be that is the question'
def text_gen(model,seed,rand=5,h_size=32,size=100):
    n = len(seed)
    one_hot = torch.zeros(n,27)
    for i in range(n):
        one_hot[i] = char_dict[seed[i]]
    hidden = torch.zeros(hiddensz,1),torch.zeros(hiddensz,1)
    last_char = ''
    for vec in one_hot:
        y_hat,hidden = model(vec.unsqueeze(1),hidden)
        out = y_hat.permute((1,0))
    char = letters[torch.argmax(out)]
    seed += char
    for i in range(size):
        last_char = char
        y_hat,hidden = model(char_dict[last_char].unsqueeze(1),hidden)
        out = y_hat.permute((1,0))
        if last_char == ' ':
            best = torch.argsort(out)
            best = best[-rand:]
            char = np.random.choice(best.squeeze(0))
            char = letters[char]
        else:
            char = torch.argmax(out)
            char = letters[char]
        seed += char
    return seed

# %%
train = customDataset(D)
train_loader = DataLoader(train,batch_size = 1, shuffle = False)
lr = .001
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ### We truncated the back propogation to speed things up. You can try different values of truncation to see how it performs.
#
# ### DB COMMENT: Is this really truncation as we usually understand it?  It looks like we're just ignoring most of the training data via this "truncation term"...

# %%
n_epochs = 30
truncate = 50
for epoch in range(1, n_epochs + 1):
    model.train()
    hidden = torch.zeros(hiddensz,1),torch.zeros(hiddensz,1)
    losslist = []
    i = 1
    loss = 0
    for d,t in train_loader:
        if i%truncate==0:
            loss.backward(retain_graph=True)
            optimizer.step()
            optimizer.zero_grad()
            loss = 0
            hidden = (hidden[0].data,hidden[1].data)
        output, hidden = model(d.permute((1,0)),hidden)
        loss += criterion(output.permute((1,0)),t.argmax(dim=1))
        losslist.append(loss.item())
        i += 1
    print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
    print("training: {:.4f}".format(np.mean(losslist)))
    model.eval()
    print(text_gen(model,seed,size=1000,rand=10,h_size=hiddensz))
# Out:
# Epoch: 1/30............. training: 34.5783
# to be or not to be that is the question qims zeep die pood uno uelend refould for king gring of in consence your qaven qo qild when my ours for consente that my for bratses qingt but press zinter heart qo the right the onces jote hath jover respice i lith zinty unsees of xim king ear joy xell a zear praise gone part vider unsering for thee and for joy your xin joy or one thee can dear your zear qo and is prive king ure of beauty zeep when my for reserved prease your rese endred unus with earth eyes not life in streng jount bear xim kin zinger king my heart know unser respred of the war for his his orn sun  an rearer prain in vering shall a unseare do zing unlooked for press when now grains live qo him xim no nor joy qrear my eless eyes beauty with prove give make unous his qrust virth qingert when grace jove your gain end with rest qo your heart love do king or uns inatereon the ulsed of nor joy be the war for reserved love do your vert king hanging for unther confounded grom shall unlom jove hand virtur of present grace dot
# Epoch: 2/30............. training: 34.2025
# to be or not to be that is the question age your all from zepring xin zell rest prive  zent a  kine hore qress prove mine qor you when grace king shall zeep my grace in earth and zere shall vise more love of see beart doth decay recurve go our the vien  me far of winger in xim reaves eyes your beauty and can chacked mare unlet decay in provery with viety cheep i  confert for of qo proone by dear graced return make cheely xin a inath when grace qill and xin be dear mare your king beauty shall  but reakent your vert veaulst doth preas king line live for zent  vering hand can xill the zenthe  qad qo joy change i zear you your qecease and part  qat for no string the heart unlet for his sin gave eyele the now had earth when you in joy xell shall with make hant  xat be respilled in zeary ending for zenthe unset from joy recurve love reserved nother can qo my all from in reas shall qo in xtres doth not for in xim you should not every and xin the zing eye of sead and is which primine xin with earth like uno qain bear eye vinty look
# Epoch: 3/30............. training: 33.9083
# to be or not to be that is the question agains  on it hore do love uno rease xin live rest the jours qo king which  rear and part my it not so long grace with the now grooked  bade unto shall king look than king death contert king in vering eyes the glace joy have reas qith jounst he hare hand nor dare resing jo bright refouns contrand and for qone xim contrent every beauty nor which vietern prease where you when contrich love unsear not it beauty qart nou nath heart and i in prace dear your every rest grove inate prood in qo joy priving by is joy unlook part your that jour known vering ine but know zeep hore the part eyes where joy unlooked mare unlous contrect qithing given your jove gived dear when viser nor nor on eyel joy of bear king knen respint zie with priving of  omemers zear fresh your beauty jovery earth qo unlet of the breast look part xath a tor provery xin of and xin vinty doth for resement shall with qon have  an stay give unseen love doth with so or gain dear of beauty can his riss ridour and reasure shall a
# Epoch: 4/30............. training: 33.6935
# to be or not to be that is the question consent recouth jayst gracion ne gives with give zing kin be dieh zitly qive unlow be still with jain unlooked  but xelled unuring grace your can the qight decease for recare more her shadow so kill jountear gain zied woo  for do artin meave lit ride whold her jeppick xithid qishing jounst for knownong earth xar live your live unlet a stool prive my jewe unsence venst recurnion peristed joy recure be beauty heart which  mad grace of recounting grief made o dear that gring even more reaven xim vering even joves when recort lives not make unused xin singers pressads gook for do orn your confound for xtarced sear dear my joved  coon joy nothing kning not xad you zess jove hade nor hath xich priever unther hath retund qweet king and uniet joves king cheal jute bring nor heary not unshe can for kish with viet qivelfsed unto virnt my verse days are look ridere  hose your rectouns lies excuring jouns the eyes by entith qifther with whenry and there in it reams like nor hath thee my frown king
# Epoch: 30/30............. training: 31.0571
# to be or not to be that is the question kisplies  form xtore roself lives of thy now made  keep jough by of the your of qear give excuse unour my wouth doth xir of unsearth kild edder qine live qing that prove jop zear hast xim xeloved but us if govers hath unour not as you vaintst you unused death for use xim you the worldent goved love your hath blooded which zettrotion keep doth jowned your or zilland  andored with loss and give xell vistence xing he unsed with cheef i summers  doth beauty beauty qarthar jouns kies his condouteon despase inale condoure yet beauty for his  jow endet come up mak unlet have nor it joy live knoly decay goven upe sees jove jound unlom sulfol know beauining xerest grace king venen is firsheng by reppict vering from xtooly but kneth of this sings by unsedot jover king thou ke rade zent my shadows nor sweet xecold with thee in xelithts of a confound zies vens xponglete qon from when from the alounged your or parts doth all the then shall outle vines eyes jown contrange pist you whose xingth whent

# %%
n_epochs = 30
truncate = 10
for epoch in range(1, n_epochs + 1):
    model.train()
    hidden = torch.zeros(hiddensz,1),torch.zeros(hiddensz,1)
    losslist = []
    i = 1
    loss = 0
    for d,t in train_loader:
        if i%truncate==0:
            loss.backward(retain_graph=True)
            optimizer.step()
            optimizer.zero_grad()
            loss = 0
            hidden = (hidden[0].data,hidden[1].data)
        output, hidden = model(d.permute((1,0)),hidden)
        loss += criterion(output.permute((1,0)),t.argmax(dim=1))
        losslist.append(loss.item())
        i += 1
    print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
    print("training: {:.4f}".format(np.mean(losslist)))
    model.eval()
    print(text_gen(model,seed,size=1000,rand=10,h_size=hiddensz))
# Out:
# Epoch: 1/30............. training: 6.8087
# to be or not to be that is the question jewelly jost grack xir as king in zhich qight destroused shall his his rass you a xelftion zeeth thinker night lie zened your one that shall his for receivest vist for when do unleth night jow  so true a ruth virte king reast xports undoured lies and  verilves your days rome noth kine shall zent qarthards inate jo king sun joy be still proene uniohs his crunt jovery now jove grace and part  dother dearits the xinces bristless eyes qeeply beauty griens rectance doth graced mare respected qingth frome with earth not part veasure live king dear qo you live rhom zith may return of dived gints zeeply qor when in every with look but king qravely mand his youth you zear zet nor xen live stole jo jown you live unlous now parts unlose how with streaved joth kind place qine eyes recarves eves unlooked hand jearths his for  jow end can dear your zear love part even zie your self the ure thenry heart know and gain viets to then live from leake unalted for king when come you in ven jovery beauty li
# Epoch: 2/30............. training: 7.2528
